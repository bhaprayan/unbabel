# %%
import torch.nn
import torchaudio

import numpy as np
from shutil import copyfile
import sklearn
import os
import glob
from tqdm import tqdm

from datasets import PollyClassificationDataset

import matplotlib.pyplot as plt
# %matplotlib inline

import time

# %%
train_dataset = PollyClassificationDataset('PollyClassificationData/train')
# train_dataset.audioFileNames[0]
train_dataset[0]
# Out:
# Tranform applied to data is: Spectrogram()
# file name: PollyClassificationData/train/uk/abortions.After_uk.mp3
# (tensor([[[[-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096],
#            [-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096],
#            [-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096],
#            ...,
#            [-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096],
#            [-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096],
#            [-16.6096, -16.6096, -16.6096,  ..., -16.6096, -16.6096, -16.6096]]]]),
#  0)

# %%
import random
random_indexes = random.sample(range(len(train_dataset)), 15)
for i in random_indexes:
    plt.imshow(train_dataset[i][0].squeeze())
    plt.show()
# Out:
# file name: PollyClassificationData/train/us/nutritious_us.mp3
# file name: PollyClassificationData/train/us/right?_us.mp3
# file name: PollyClassificationData/train/uk/administration.No_uk.mp3
# file name: PollyClassificationData/train/us/2016,_us.mp3
# file name: PollyClassificationData/train/us/figured_us.mp3
# file name: PollyClassificationData/train/uk/deliver_uk.mp3
# file name: PollyClassificationData/train/us/stillbirths,_us.mp3
# file name: PollyClassificationData/train/uk/remedies.The_uk.mp3
# file name: PollyClassificationData/train/us/quilt_us.mp3
# file name: PollyClassificationData/train/uk/Cuomo,_uk.mp3
# file name: PollyClassificationData/train/uk/one-third_uk.mp3
# file name: PollyClassificationData/train/us/uncover_us.mp3
# file name: PollyClassificationData/train/us/mid-1990s,_us.mp3
# file name: PollyClassificationData/train/us/downed_us.mp3
# file name: PollyClassificationData/train/us/feels_us.mp3
